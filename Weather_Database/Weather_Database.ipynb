# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Import the API key.
from config1 import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4da4606cb24a088008d28abfceda0e9c

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]  
        
        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pacific grove
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | berlevag
# Processing Record 11 of Set 1 | constitucion
# Processing Record 12 of Set 1 | saint-pierre
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | kavieng
# Processing Record 15 of Set 1 | buariki
# City not found. Skipping...
# Processing Record 16 of Set 1 | aklavik
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | mopti
# Processing Record 19 of Set 1 | alghero
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | madras
# Processing Record 23 of Set 1 | caravelas
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | celestun
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | rognan
# Processing Record 28 of Set 1 | engel-yurt
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | fort nelson
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | saint george
# Processing Record 33 of Set 1 | san patricio
# Processing Record 34 of Set 1 | trat
# Processing Record 35 of Set 1 | umm lajj
# Processing Record 36 of Set 1 | kysyl-syr
# Processing Record 37 of Set 1 | barentu
# Processing Record 38 of Set 1 | mayo
# Processing Record 39 of Set 1 | beloha
# Processing Record 40 of Set 1 | udachnyy
# Processing Record 41 of Set 1 | new norfolk
# Processing Record 42 of Set 1 | voyvozh
# Processing Record 43 of Set 1 | ziyamet
# City not found. Skipping...
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | bonavista
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | hay river
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | bandarbeyla
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | okoneshnikovo
# Processing Record 7 of Set 2 | kaitangata
# Processing Record 8 of Set 2 | nome
# Processing Record 9 of Set 2 | moron
# Processing Record 10 of Set 2 | vila
# Processing Record 11 of Set 2 | mormugao
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | tuktoyaktuk
# Processing Record 14 of Set 2 | grindavik
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | alice springs
# Processing Record 22 of Set 2 | cockburn town
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | shahdadkot
# Processing Record 27 of Set 2 | auki
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | ketchikan
# Processing Record 30 of Set 2 | montepuez
# Processing Record 31 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 2 | meulaboh
# Processing Record 33 of Set 2 | dongsheng
# Processing Record 34 of Set 2 | bluff
# Processing Record 35 of Set 2 | kavaratti
# Processing Record 36 of Set 2 | macia
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | vardo
# Processing Record 39 of Set 2 | hovd
# Processing Record 40 of Set 2 | katsuura
# Processing Record 41 of Set 2 | opuwo
# Processing Record 42 of Set 2 | nyrob
# Processing Record 43 of Set 2 | clyde river
# Processing Record 44 of Set 2 | mana
# Processing Record 45 of Set 2 | olafsvik
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | hosdurga
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | clarence town
# Processing Record 50 of Set 2 | lasa
# Processing Record 1 of Set 3 | klaksvik
# Processing Record 2 of Set 3 | senigallia
# Processing Record 3 of Set 3 | sobolevo
# Processing Record 4 of Set 3 | tessalit
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | mareeba
# Processing Record 8 of Set 3 | sao joao da barra
# Processing Record 9 of Set 3 | bukachacha
# Processing Record 10 of Set 3 | matsuura
# Processing Record 11 of Set 3 | saint-leu
# Processing Record 12 of Set 3 | leningradskiy
# Processing Record 13 of Set 3 | ilulissat
# Processing Record 14 of Set 3 | coihaique
# Processing Record 15 of Set 3 | bacalar
# Processing Record 16 of Set 3 | puerto ayora
# Processing Record 17 of Set 3 | asau
# Processing Record 18 of Set 3 | port alfred
# Processing Record 19 of Set 3 | ilo
# Processing Record 20 of Set 3 | rio verde de mato grosso
# Processing Record 21 of Set 3 | souris
# Processing Record 22 of Set 3 | axim
# Processing Record 23 of Set 3 | cape town
# Processing Record 24 of Set 3 | lalibela
# Processing Record 25 of Set 3 | karmana
# City not found. Skipping...
# Processing Record 26 of Set 3 | joshimath
# Processing Record 27 of Set 3 | tipitapa
# Processing Record 28 of Set 3 | salalah
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 3 | erzin
# Processing Record 32 of Set 3 | tuatapere
# Processing Record 33 of Set 3 | lavrentiya
# Processing Record 34 of Set 3 | vostok
# Processing Record 35 of Set 3 | souillac
# Processing Record 36 of Set 3 | itarema
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 39 of Set 3 | bambous virieux
# Processing Record 40 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 41 of Set 3 | xuanhua
# Processing Record 42 of Set 3 | bubaque
# Processing Record 43 of Set 3 | kurilsk
# Processing Record 44 of Set 3 | rawson
# Processing Record 45 of Set 3 | tangara
# Processing Record 46 of Set 3 | tiznit
# Processing Record 47 of Set 3 | adeje
# Processing Record 48 of Set 3 | faanui
# Processing Record 49 of Set 3 | carnarvon
# Processing Record 50 of Set 3 | praia
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | la esperanza
# Processing Record 3 of Set 4 | gbadolite
# Processing Record 4 of Set 4 | olinda
# Processing Record 5 of Set 4 | torbay
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | cortez
# Processing Record 8 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 4 | guanica
# Processing Record 10 of Set 4 | naliya
# Processing Record 11 of Set 4 | tomatlan
# Processing Record 12 of Set 4 | chimore
# Processing Record 13 of Set 4 | buala
# Processing Record 14 of Set 4 | shangrao
# Processing Record 15 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 4 | lata
# Processing Record 17 of Set 4 | port-cartier
# Processing Record 18 of Set 4 | brasilia
# Processing Record 19 of Set 4 | mazara del vallo
# Processing Record 20 of Set 4 | marsala
# Processing Record 21 of Set 4 | voh
# Processing Record 22 of Set 4 | diffa
# Processing Record 23 of Set 4 | mount gambier
# Processing Record 24 of Set 4 | saint-fabien
# City not found. Skipping...
# Processing Record 25 of Set 4 | wattegama
# Processing Record 26 of Set 4 | alta floresta
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | mugur-aksy
# Processing Record 29 of Set 4 | dalvik
# Processing Record 30 of Set 4 | santa cruz
# Processing Record 31 of Set 4 | baoqing
# Processing Record 32 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 4 | cherskiy
# Processing Record 34 of Set 4 | nanortalik
# Processing Record 35 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 4 | mar del plata
# Processing Record 37 of Set 4 | banjar
# Processing Record 38 of Set 4 | te anau
# Processing Record 39 of Set 4 | arraial do cabo
# Processing Record 40 of Set 4 | sakakah
# Processing Record 41 of Set 4 | richards bay
# Processing Record 42 of Set 4 | kyshtovka
# Processing Record 43 of Set 4 | ribeira brava
# Processing Record 44 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 4 | santa isabel do rio negro
# Processing Record 46 of Set 4 | patiya
# Processing Record 47 of Set 4 | saldanha
# Processing Record 48 of Set 4 | namibe
# Processing Record 49 of Set 4 | butaritari
# Processing Record 50 of Set 4 | marsa matruh
# Processing Record 1 of Set 5 | hasaki
# Processing Record 2 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | najran
# Processing Record 5 of Set 5 | dharchula
# Processing Record 6 of Set 5 | mallig
# Processing Record 7 of Set 5 | babol
# Processing Record 8 of Set 5 | lephepe
# City not found. Skipping...
# Processing Record 9 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 5 | ahipara
# Processing Record 11 of Set 5 | mangualde
# Processing Record 12 of Set 5 | laguna
# Processing Record 13 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 5 | thunder bay
# Processing Record 15 of Set 5 | swetes
# Processing Record 16 of Set 5 | akureyri
# Processing Record 17 of Set 5 | lompoc
# Processing Record 18 of Set 5 | hofn
# Processing Record 19 of Set 5 | kargasok
# Processing Record 20 of Set 5 | smidovich
# Processing Record 21 of Set 5 | muyezerskiy
# Processing Record 22 of Set 5 | haines junction
# Processing Record 23 of Set 5 | bundaberg
# Processing Record 24 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 5 | asfi
# Processing Record 26 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 5 | muromtsevo
# Processing Record 28 of Set 5 | ayios matthaios
# City not found. Skipping...
# Processing Record 29 of Set 5 | rutland
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | tagusao
# Processing Record 32 of Set 5 | hobyo
# Processing Record 33 of Set 5 | bonthe
# Processing Record 34 of Set 5 | shubarshi
# Processing Record 35 of Set 5 | zinder
# Processing Record 36 of Set 5 | tyshkivka
# Processing Record 37 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 5 | belchatow
# Processing Record 39 of Set 5 | somerset
# Processing Record 40 of Set 5 | naze
# Processing Record 41 of Set 5 | newport
# Processing Record 42 of Set 5 | noumea
# Processing Record 43 of Set 5 | cidreira
# Processing Record 44 of Set 5 | vestmannaeyjar
# Processing Record 45 of Set 5 | altamont
# Processing Record 46 of Set 5 | mogadishu
# Processing Record 47 of Set 5 | pucara
# Processing Record 48 of Set 5 | airai
# Processing Record 49 of Set 5 | padang
# Processing Record 50 of Set 5 | mossendjo
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | hami
# Processing Record 3 of Set 6 | awjilah
# Processing Record 4 of Set 6 | acapulco
# Processing Record 5 of Set 6 | jumla
# Processing Record 6 of Set 6 | margate
# Processing Record 7 of Set 6 | nadym
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | esmeraldas
# Processing Record 10 of Set 6 | teguldet
# Processing Record 11 of Set 6 | bodden town
# Processing Record 12 of Set 6 | sola
# Processing Record 13 of Set 6 | palafrugell
# Processing Record 14 of Set 6 | baijiantan
# Processing Record 15 of Set 6 | cayenne
# Processing Record 16 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 6 | dikson
# Processing Record 18 of Set 6 | camopi
# Processing Record 19 of Set 6 | deputatskiy
# Processing Record 20 of Set 6 | tiksi
# Processing Record 21 of Set 6 | sitka
# Processing Record 22 of Set 6 | georgetown
# Processing Record 23 of Set 6 | cairns
# Processing Record 24 of Set 6 | sinop
# Processing Record 25 of Set 6 | molepolole
# Processing Record 26 of Set 6 | port antonio
# Processing Record 27 of Set 6 | seoul
# Processing Record 28 of Set 6 | mattru
# Processing Record 29 of Set 6 | laureles
# Processing Record 30 of Set 6 | biloela
# Processing Record 31 of Set 6 | shar
# Processing Record 32 of Set 6 | jiangkou
# Processing Record 33 of Set 6 | hvammstangi
# City not found. Skipping...
# Processing Record 34 of Set 6 | aksarka
# Processing Record 35 of Set 6 | lazaro cardenas
# Processing Record 36 of Set 6 | mago
# Processing Record 37 of Set 6 | jaisalmer
# Processing Record 38 of Set 6 | kashi
# Processing Record 39 of Set 6 | inhambane
# Processing Record 40 of Set 6 | belyy yar
# Processing Record 41 of Set 6 | villarrica
# Processing Record 42 of Set 6 | severo-kurilsk
# Processing Record 43 of Set 6 | sungaipenuh
# Processing Record 44 of Set 6 | talara
# Processing Record 45 of Set 6 | bell ville
# Processing Record 46 of Set 6 | smithers
# Processing Record 47 of Set 6 | ifakara
# Processing Record 48 of Set 6 | mallasamudram
# Processing Record 49 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 6 | coquimbo
# Processing Record 1 of Set 7 | la union
# Processing Record 2 of Set 7 | tarashcha
# Processing Record 3 of Set 7 | son la
# Processing Record 4 of Set 7 | abu kamal
# Processing Record 5 of Set 7 | spitsevka
# Processing Record 6 of Set 7 | villa carlos paz
# Processing Record 7 of Set 7 | kutum
# Processing Record 8 of Set 7 | key west
# Processing Record 9 of Set 7 | erenhot
# Processing Record 10 of Set 7 | flinders
# Processing Record 11 of Set 7 | stornoway
# Processing Record 12 of Set 7 | inuvik
# Processing Record 13 of Set 7 | srednekolymsk
# Processing Record 14 of Set 7 | edson
# Processing Record 15 of Set 7 | odweyne
# Processing Record 16 of Set 7 | barkhan
# Processing Record 17 of Set 7 | pogar
# Processing Record 18 of Set 7 | formosa
# Processing Record 19 of Set 7 | horsham
# Processing Record 20 of Set 7 | labuan
# Processing Record 21 of Set 7 | shimoda
# Processing Record 22 of Set 7 | sumkino
# Processing Record 23 of Set 7 | los llanos de aridane
# Processing Record 24 of Set 7 | akyab
# Processing Record 25 of Set 7 | castro
# Processing Record 26 of Set 7 | birsk
# Processing Record 27 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 7 | wajir
# Processing Record 29 of Set 7 | cabinda
# Processing Record 30 of Set 7 | birjand
# Processing Record 31 of Set 7 | altay
# Processing Record 32 of Set 7 | mahebourg
# Processing Record 33 of Set 7 | colares
# Processing Record 34 of Set 7 | bilibino
# Processing Record 35 of Set 7 | waingapu
# Processing Record 36 of Set 7 | along
# Processing Record 37 of Set 7 | esperance
# Processing Record 38 of Set 7 | miles city
# Processing Record 39 of Set 7 | gola gokarannath
# Processing Record 40 of Set 7 | bossangoa
# Processing Record 41 of Set 7 | guerrero negro
# Processing Record 42 of Set 7 | kununurra
# Processing Record 43 of Set 7 | bone
# Processing Record 44 of Set 7 | seymchan
# Processing Record 45 of Set 7 | chateauneuf-les-martigues
# Processing Record 46 of Set 7 | vila franca do campo
# Processing Record 47 of Set 7 | mpulungu
# Processing Record 48 of Set 7 | kayerkan
# Processing Record 49 of Set 7 | amga
# Processing Record 50 of Set 7 | brae
# Processing Record 1 of Set 8 | qidong
# Processing Record 2 of Set 8 | quepos
# Processing Record 3 of Set 8 | lagoa
# Processing Record 4 of Set 8 | port hardy
# Processing Record 5 of Set 8 | samana
# Processing Record 6 of Set 8 | namatanai
# Processing Record 7 of Set 8 | carmo do cajuru
# Processing Record 8 of Set 8 | mehamn
# Processing Record 9 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 10 of Set 8 | yanam
# Processing Record 11 of Set 8 | san jose
# Processing Record 12 of Set 8 | sorland
# Processing Record 13 of Set 8 | marzuq
# Processing Record 14 of Set 8 | krasnokamensk
# Processing Record 15 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 8 | hat yai
# Processing Record 18 of Set 8 | ginda
# Processing Record 19 of Set 8 | kupang
# Processing Record 20 of Set 8 | rodrigues alves
# Processing Record 21 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of Set 8 | safaqis
# City not found. Skipping...
# Processing Record 23 of Set 8 | tual
# Processing Record 24 of Set 8 | bauchi
# Processing Record 25 of Set 8 | shingu
# Processing Record 26 of Set 8 | sabang
# Processing Record 27 of Set 8 | dingle
# Processing Record 28 of Set 8 | isangel
# Processing Record 29 of Set 8 | llano de piedra
# Processing Record 30 of Set 8 | nizwa
# Processing Record 31 of Set 8 | mezen
# Processing Record 32 of Set 8 | rosarito
# Processing Record 33 of Set 8 | mecca
# Processing Record 34 of Set 8 | humaita
# Processing Record 35 of Set 8 | baruun-urt
# Processing Record 36 of Set 8 | malinyi
# Processing Record 37 of Set 8 | bilma
# Processing Record 38 of Set 8 | roma
# Processing Record 39 of Set 8 | saint-joseph
# Processing Record 40 of Set 8 | domoni
# Processing Record 41 of Set 8 | dwarka
# Processing Record 42 of Set 8 | benicarlo
# Processing Record 43 of Set 8 | heishan
# Processing Record 44 of Set 8 | ostrovnoy
# Processing Record 45 of Set 8 | salihorsk
# Processing Record 46 of Set 8 | omsukchan
# Processing Record 47 of Set 8 | poso
# Processing Record 48 of Set 8 | filingue
# Processing Record 49 of Set 8 | carballo
# Processing Record 50 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 9 | acarau
# Processing Record 2 of Set 9 | oruro
# Processing Record 3 of Set 9 | mataram
# Processing Record 4 of Set 9 | aquiraz
# Processing Record 5 of Set 9 | ancud
# Processing Record 6 of Set 9 | stepnyak
# Processing Record 7 of Set 9 | luderitz
# Processing Record 8 of Set 9 | sambava
# Processing Record 9 of Set 9 | bjornevatn
# Processing Record 10 of Set 9 | port hedland
# Processing Record 11 of Set 9 | kabansk
# Processing Record 12 of Set 9 | yar-sale
# Processing Record 13 of Set 9 | diego de almagro
# Processing Record 14 of Set 9 | tura
# Processing Record 15 of Set 9 | sioux lookout
# Processing Record 16 of Set 9 | aykhal
# Processing Record 17 of Set 9 | labuhan
# Processing Record 18 of Set 9 | yarmouth
# Processing Record 19 of Set 9 | puerto baquerizo moreno
# Processing Record 20 of Set 9 | tefe
# Processing Record 21 of Set 9 | ono
# Processing Record 22 of Set 9 | tilichiki
# Processing Record 23 of Set 9 | ocampo
# Processing Record 24 of Set 9 | chumikan
# Processing Record 25 of Set 9 | porto murtinho
# Processing Record 26 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 28 of Set 9 | solnechnyy
# Processing Record 29 of Set 9 | urumqi
# Processing Record 30 of Set 9 | santa rosa
# Processing Record 31 of Set 9 | genhe
# Processing Record 32 of Set 9 | egvekinot
# Processing Record 33 of Set 9 | nyurba
# Processing Record 34 of Set 9 | kushima
# Processing Record 35 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 9 | ilhabela
# Processing Record 37 of Set 9 | kamaishi
# Processing Record 38 of Set 9 | ouesso
# Processing Record 39 of Set 9 | lakes entrance
# Processing Record 40 of Set 9 | anori
# Processing Record 41 of Set 9 | general roca
# Processing Record 42 of Set 9 | zhigansk
# Processing Record 43 of Set 9 | haimen
# Processing Record 44 of Set 9 | moree
# Processing Record 45 of Set 9 | keskin
# Processing Record 46 of Set 9 | praia da vitoria
# Processing Record 47 of Set 9 | thessalon
# Processing Record 48 of Set 9 | san cristobal
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | candolim
# Processing Record 1 of Set 10 | kajaani
# Processing Record 2 of Set 10 | meadow lake
# Processing Record 3 of Set 10 | flin flon
# Processing Record 4 of Set 10 | phnum penh
# City not found. Skipping...
# Processing Record 5 of Set 10 | stockholm
# Processing Record 6 of Set 10 | novobiryusinskiy
# Processing Record 7 of Set 10 | balikpapan
# Processing Record 8 of Set 10 | mushie
# Processing Record 9 of Set 10 | dunedin
# Processing Record 10 of Set 10 | vyshkov
# Processing Record 11 of Set 10 | atar
# Processing Record 12 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 10 | arroyo
# Processing Record 14 of Set 10 | paamiut
# Processing Record 15 of Set 10 | sao filipe
# Processing Record 16 of Set 10 | tucuman
# Processing Record 17 of Set 10 | greytown
# Processing Record 18 of Set 10 | citeureup
# Processing Record 19 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 10 | guantanamo
# Processing Record 21 of Set 10 | sal rei
# Processing Record 22 of Set 10 | puerto cortes
# City not found. Skipping...
# Processing Record 23 of Set 10 | touros
# Processing Record 24 of Set 10 | vila velha
# Processing Record 25 of Set 10 | fortuna
# Processing Record 26 of Set 10 | socorro
# Processing Record 27 of Set 10 | hauterive
# Processing Record 28 of Set 10 | bengkulu
# Processing Record 29 of Set 10 | kingston upon hull
# Processing Record 30 of Set 10 | esil
# Processing Record 31 of Set 10 | yabelo
# Processing Record 32 of Set 10 | leshukonskoye
# Processing Record 33 of Set 10 | dongning
# Processing Record 34 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 35 of Set 10 | linjiang
# Processing Record 36 of Set 10 | ust-barguzin
# Processing Record 37 of Set 10 | tulcingo
# City not found. Skipping...
# Processing Record 38 of Set 10 | marsh harbour
# Processing Record 39 of Set 10 | pacifica
# Processing Record 40 of Set 10 | half moon bay
# Processing Record 41 of Set 10 | tarui
# Processing Record 42 of Set 10 | russell
# Processing Record 43 of Set 10 | kirovskiy
# Processing Record 44 of Set 10 | yining
# Processing Record 45 of Set 10 | maragogi
# Processing Record 46 of Set 10 | denpasar
# Processing Record 47 of Set 10 | sur
# Processing Record 48 of Set 10 | mount isa
# Processing Record 49 of Set 10 | zyryanka
# Processing Record 50 of Set 10 | uberaba
# Processing Record 1 of Set 11 | jarjis
# City not found. Skipping...
# Processing Record 2 of Set 11 | lorengau
# Processing Record 3 of Set 11 | soliera
# Processing Record 4 of Set 11 | khani
# Processing Record 5 of Set 11 | oshkosh
# Processing Record 6 of Set 11 | vwawa
# Processing Record 7 of Set 11 | batu gajah
# Processing Record 8 of Set 11 | tezu
# Processing Record 9 of Set 11 | salinopolis
# Processing Record 10 of Set 11 | betare oya
# Processing Record 11 of Set 11 | yushu
# Processing Record 12 of Set 11 | aljezur
# Processing Record 13 of Set 11 | badnawar
# Processing Record 14 of Set 11 | hamilton
# Processing Record 15 of Set 11 | cravo norte
# Processing Record 16 of Set 11 | carutapera
# Processing Record 17 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 18 of Set 11 | poum
# Processing Record 19 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 11 | ranong
# Processing Record 21 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 11 | narsaq
# Processing Record 23 of Set 11 | sydney
# Processing Record 24 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 11 | balabac
# Processing Record 26 of Set 11 | beringovskiy
# Processing Record 27 of Set 11 | la palma del condado
# Processing Record 28 of Set 11 | avera
# Processing Record 29 of Set 11 | honningsvag
# Processing Record 30 of Set 11 | aldan
# Processing Record 31 of Set 11 | aland
# Processing Record 32 of Set 11 | moose factory
# Processing Record 33 of Set 11 | bosaso
# Processing Record 34 of Set 11 | mbandaka
# Processing Record 35 of Set 11 | evensk
# Processing Record 36 of Set 11 | vanderhoof
# Processing Record 37 of Set 11 | plettenberg bay
# Processing Record 38 of Set 11 | tacuarembo
# Processing Record 39 of Set 11 | birin
# Processing Record 40 of Set 11 | komsomolskiy
# Processing Record 41 of Set 11 | ambilobe
# Processing Record 42 of Set 11 | douglas
# Processing Record 43 of Set 11 | kenai
# Processing Record 44 of Set 11 | palu
# Processing Record 45 of Set 11 | burica
# City not found. Skipping...
# Processing Record 46 of Set 11 | teacapan
# Processing Record 47 of Set 11 | launceston
# Processing Record 48 of Set 11 | rosetta
# Processing Record 49 of Set 11 | kiruna
# Processing Record 50 of Set 11 | tabas
# Processing Record 1 of Set 12 | kyaikto
# Processing Record 2 of Set 12 | kota belud
# Processing Record 3 of Set 12 | dickinson
# Processing Record 4 of Set 12 | san juan
# Processing Record 5 of Set 12 | gorodets
# Processing Record 6 of Set 12 | mango
# Processing Record 7 of Set 12 | binghamton
# Processing Record 8 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 12 | saint anthony
# Processing Record 10 of Set 12 | xinqing
# Processing Record 11 of Set 12 | abu dhabi
# Processing Record 12 of Set 12 | ornskoldsvik
# Processing Record 13 of Set 12 | kruisfontein
# Processing Record 14 of Set 12 | novikovo
# Processing Record 15 of Set 12 | muros
# Processing Record 16 of Set 12 | kahului
# Processing Record 17 of Set 12 | farah
# Processing Record 18 of Set 12 | shellbrook
# Processing Record 19 of Set 12 | hutang
# Processing Record 20 of Set 12 | atambua
# Processing Record 21 of Set 12 | sterling
# Processing Record 22 of Set 12 | areka
# Processing Record 23 of Set 12 | college
# Processing Record 24 of Set 12 | cheremukhovo
# Processing Record 25 of Set 12 | lakatoro
# Processing Record 26 of Set 12 | tanggu
# Processing Record 27 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 12 | honiara
# Processing Record 29 of Set 12 | jiexiu
# Processing Record 30 of Set 12 | herzberg
# Processing Record 31 of Set 12 | grand gaube
# Processing Record 32 of Set 12 | geraldton
# Processing Record 33 of Set 12 | burnie
# Processing Record 34 of Set 12 | lapinigan
# Processing Record 35 of Set 12 | litovko
# Processing Record 36 of Set 12 | bumba
# Processing Record 37 of Set 12 | independence
# Processing Record 38 of Set 12 | lincoln
# Processing Record 39 of Set 12 | ternate
# Processing Record 40 of Set 12 | sao felix do xingu
# Processing Record 41 of Set 12 | high level
# Processing Record 42 of Set 12 | karratha
# Processing Record 43 of Set 12 | adrar
# Processing Record 44 of Set 12 | faya
# Processing Record 45 of Set 12 | pudozh
# Processing Record 46 of Set 12 | riverbank
# Processing Record 47 of Set 12 | price
# Processing Record 48 of Set 12 | sao jose de ribamar
# Processing Record 49 of Set 12 | mahonda
# Processing Record 50 of Set 12 | ondjiva
# Processing Record 1 of Set 13 | kirakira
# Processing Record 2 of Set 13 | hambantota
# Processing Record 3 of Set 13 | bocas del toro
# Processing Record 4 of Set 13 | tailai
# Processing Record 5 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 6 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 7 of Set 13 | tecoanapa
# Processing Record 8 of Set 13 | guiratinga
# Processing Record 9 of Set 13 | harnosand
# Processing Record 10 of Set 13 | el alto
# Processing Record 11 of Set 13 | khowst
# Processing Record 12 of Set 13 | moissala
# Processing Record 13 of Set 13 | mayumba
# Processing Record 14 of Set 13 | san quintin
# Processing Record 15 of Set 13 | lahij
# Processing Record 16 of Set 13 | palmer
# Processing Record 17 of Set 13 | san policarpo
# Processing Record 18 of Set 13 | nisia floresta
# Processing Record 19 of Set 13 | wilmington
# Processing Record 20 of Set 13 | minas
# Processing Record 21 of Set 13 | luwuk
# Processing Record 22 of Set 13 | copiapo
# Processing Record 23 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 13 | dudesti
# Processing Record 25 of Set 13 | maputo
# Processing Record 26 of Set 13 | saquisili
# Processing Record 27 of Set 13 | maceio
# Processing Record 28 of Set 13 | dukat
# Processing Record 29 of Set 13 | voghera
# Processing Record 30 of Set 13 | yeppoon
# Processing Record 31 of Set 13 | sept-iles
# Processing Record 32 of Set 13 | killybegs
# Processing Record 33 of Set 13 | tres passos
# Processing Record 34 of Set 13 | roald
# Processing Record 35 of Set 13 | kerema
# Processing Record 36 of Set 13 | motygino
# Processing Record 37 of Set 13 | zavyalovo
# Processing Record 38 of Set 13 | san carlos de bariloche
# Processing Record 39 of Set 13 | borovskoy
# Processing Record 40 of Set 13 | palkan
# Processing Record 41 of Set 13 | karasuk
# Processing Record 42 of Set 13 | lucapa
# Processing Record 43 of Set 13 | dakar
# Processing Record 44 of Set 13 | manokwari
# Processing Record 45 of Set 13 | butterworth
# Processing Record 46 of Set 13 | banda aceh
# Processing Record 47 of Set 13 | gat
# Processing Record 48 of Set 13 | kokoda
# Processing Record 49 of Set 13 | nefteyugansk
# Processing Record 50 of Set 13 | luangwa
# Processing Record 1 of Set 14 | gusinoye ozero
# Processing Record 2 of Set 14 | broome
# Processing Record 3 of Set 14 | viedma
# Processing Record 4 of Set 14 | riviere-au-renard
# Processing Record 5 of Set 14 | qingyuan
# Processing Record 6 of Set 14 | benguela
# Processing Record 7 of Set 14 | camacha
# Processing Record 8 of Set 14 | ust-nera
# Processing Record 9 of Set 14 | morgan city
# Processing Record 10 of Set 14 | lapeer
# Processing Record 11 of Set 14 | leticia
# Processing Record 12 of Set 14 | razgrad
# Processing Record 13 of Set 14 | almaznyy
# Processing Record 14 of Set 14 | saint-augustin
# Processing Record 15 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 16 of Set 14 | skibotn
# Processing Record 17 of Set 14 | sri aman
# Processing Record 18 of Set 14 | santa maria
# Processing Record 19 of Set 14 | suruc
# Processing Record 20 of Set 14 | slave lake
# Processing Record 21 of Set 14 | thongwa
# Processing Record 22 of Set 14 | mongu
# Processing Record 23 of Set 14 | marawi
# Processing Record 24 of Set 14 | suez
# Processing Record 25 of Set 14 | dalsingh sarai
# Processing Record 26 of Set 14 | tanete
# Processing Record 27 of Set 14 | swift current
# Processing Record 28 of Set 14 | kiunga
# Processing Record 29 of Set 14 | jieshi
# Processing Record 30 of Set 14 | iskateley
# Processing Record 31 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 14 | morant bay
# Processing Record 33 of Set 14 | qasigiannguit
# Processing Record 34 of Set 14 | samarai
# Processing Record 35 of Set 14 | lewiston
# Processing Record 36 of Set 14 | porto torres
# Processing Record 37 of Set 14 | prince rupert
# Processing Record 38 of Set 14 | youkounkoun
# Processing Record 39 of Set 14 | sulangan
# Processing Record 40 of Set 14 | paramonga
# Processing Record 41 of Set 14 | virginia beach
# Processing Record 42 of Set 14 | merauke
# Processing Record 43 of Set 14 | port blair
# Processing Record 44 of Set 14 | helena
# Processing Record 45 of Set 14 | havre-saint-pierre
# Processing Record 46 of Set 14 | gunnedah
# Processing Record 47 of Set 14 | barra
# Processing Record 48 of Set 14 | bathsheba
# Processing Record 49 of Set 14 | stege
# Processing Record 50 of Set 14 | coudekerque-branche
# Processing Record 1 of Set 15 | pascagoula
# Processing Record 2 of Set 15 | fort smith
# Processing Record 3 of Set 15 | kachikau
# City not found. Skipping...
# Processing Record 4 of Set 15 | belmonte
# Processing Record 5 of Set 15 | bacolod
# Processing Record 6 of Set 15 | batouri
# Processing Record 7 of Set 15 | canton
# Processing Record 8 of Set 15 | hualmay
# Processing Record 9 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 15 | wanaka
# Processing Record 11 of Set 15 | san rafael
# Processing Record 12 of Set 15 | chifeng
# Processing Record 13 of Set 15 | havelock
# Processing Record 14 of Set 15 | aswan
# Processing Record 15 of Set 15 | beyneu
# Processing Record 16 of Set 15 | awbari
# Processing Record 17 of Set 15 | khuzhir
# Processing Record 18 of Set 15 | portland
# Processing Record 19 of Set 15 | chalchihuites
# Processing Record 20 of Set 15 | kozhva
# Processing Record 21 of Set 15 | eyl
# Processing Record 22 of Set 15 | kuusamo
# Processing Record 23 of Set 15 | matara
# Processing Record 24 of Set 15 | akdagmadeni
# Processing Record 25 of Set 15 | lokot
# Processing Record 26 of Set 15 | adre
# Processing Record 27 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 15 | volkermarkt
# City not found. Skipping...
# Processing Record 29 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 15 | rorvik
# Processing Record 31 of Set 15 | mancio lima
# Processing Record 32 of Set 15 | byron bay
# Processing Record 33 of Set 15 | ojinaga
# Processing Record 34 of Set 15 | alberton
# Processing Record 35 of Set 15 | tadine
# Processing Record 36 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 37 of Set 15 | islamkot
# Processing Record 38 of Set 15 | kilindoni
# Processing Record 39 of Set 15 | dudinka
# Processing Record 40 of Set 15 | primorsk
# Processing Record 41 of Set 15 | ngudu
# Processing Record 42 of Set 15 | arlit
# Processing Record 43 of Set 15 | magan
# Processing Record 44 of Set 15 | cap-aux-meules
# Processing Record 45 of Set 15 | puerto wilches
# Processing Record 46 of Set 15 | orlik
# Processing Record 47 of Set 15 | ola
# Processing Record 48 of Set 15 | rio grande
# Processing Record 49 of Set 15 | jalu
# Processing Record 50 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 16 | toora-khem
# Processing Record 2 of Set 16 | the valley
# Processing Record 3 of Set 16 | seguin
# Processing Record 4 of Set 16 | mogocha
# Processing Record 5 of Set 16 | ngaoundere
# Processing Record 6 of Set 16 | anadyr
# Processing Record 7 of Set 16 | semporna
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
len(city_data)
# Out:
# 692

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0  Pacific Grove  36.6177 -121.9166     59.00           clear sky        62
# 1         Avarua -21.2078 -159.7750     82.40          light rain        78
# 2        Rikitea -23.1203 -134.9692     76.98          light rain        69
# 3    Yellowknife  62.4560 -114.3525     21.00          few clouds        53
# 4          Vaini -21.2000 -175.2000     75.20    scattered clouds        78
# 5         Hobart -42.8794  147.3294     55.40    scattered clouds        67
# 6         Albany  42.6001  -73.9662     57.99          few clouds        27
# 7     Bredasdorp -34.5322   20.0403     66.20     overcast clouds        82
# 8   Punta Arenas -53.1500  -70.9167     50.00           clear sky        50
# 9       Berlevag  70.8578   29.0864     33.80          light snow        93
#
#    Cloudiness  Wind Speed Country
# 0           1       11.50      US
# 1          75       14.97      CK
# 2         100       16.58      PF
# 3          20        8.05      CA
# 4          40        8.05      TO
# 5          40        6.91      AU
# 6          14        1.99      US
# 7         100        3.44      ZA
# 8           0       18.41      CL
# 9          75        5.75      NO

# %%
#Reorder columns in city_data DataFrame
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Pacific Grove      US  36.6177 -121.9166     59.00        62           1
# 1         Avarua      CK -21.2078 -159.7750     82.40        78          75
# 2        Rikitea      PF -23.1203 -134.9692     76.98        69         100
# 3    Yellowknife      CA  62.4560 -114.3525     21.00        53          20
# 4          Vaini      TO -21.2000 -175.2000     75.20        78          40
# 5         Hobart      AU -42.8794  147.3294     55.40        67          40
# 6         Albany      US  42.6001  -73.9662     57.99        27          14
# 7     Bredasdorp      ZA -34.5322   20.0403     66.20        82         100
# 8   Punta Arenas      CL -53.1500  -70.9167     50.00        50           0
# 9       Berlevag      NO  70.8578   29.0864     33.80        93          75
#
#    Wind Speed Current Description
# 0       11.50           clear sky
# 1       14.97          light rain
# 2       16.58          light rain
# 3        8.05          few clouds
# 4        8.05    scattered clouds
# 5        6.91    scattered clouds
# 6        1.99          few clouds
# 7        3.44     overcast clouds
# 8       18.41           clear sky
# 9        5.75          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
